# %% [markdown]
# # **Prediksi Waktu Turun Salju Menggunakan Metode K-Means** <a class="anchor" id="7"></a>
# ================================================
#
# Nama : Satria Baladewa Harahap

# %% [markdown]
# ### Deskripsi Data
# Temperature --> dalam celcius
#
# Hujan --> dalam mm
#
# SinarMatahari --> jumlah jam munculnya sinar matahari
#
# Cloud3pm --> Rasio langit tertutup awan pukul 3pm

# %% [markdown]
# ## Import Module yang Dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
train_data = pd.read_csv("salju_train.csv")
test_data = pd.read_csv("salju_test.csv")

# %% [markdown]
# ## Data Exploration & Preprocessing

# %% [markdown]
# ### Data Info

# %%
train_data.info()
print("")
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109095 entries, 0 to 109094
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        109095 non-null  int64
#  1   Tanggal                   109095 non-null  object
#  2   KodeLokasi                109095 non-null  object
#  3   SuhuMin                   107973 non-null  float64
#  4   SuhuMax                   108166 non-null  float64
#  5   Hujan                     106664 non-null  float64
#  6   Penguapan                 62071 non-null   float64
#  7   SinarMatahari             56716 non-null   float64
#  8   ArahAnginTerkencang       101351 non-null  object
#  9   KecepatanAnginTerkencang  101399 non-null  float64
#  10  ArahAngin9am              101172 non-null  object
#  11  ArahAngin3pm              105898 non-null  object
#  12  KecepatanAngin9am         107742 non-null  float64
#  13  KecepatanAngin3pm         106792 non-null  float64
#  14  Kelembaban9am             107093 non-null  float64
#  15  Kelembaban3pm             105721 non-null  float64
#  16  Tekanan9am                97768 non-null   float64
#  17  Tekanan3pm                97787 non-null   float64
#  18  Awan9am                   67251 non-null   float64
#  19  Awan3pm                   64624 non-null   float64
#  20  Suhu9am                   107755 non-null  float64
#  21  Suhu3pm                   106397 non-null  float64
#  22  BersaljuHariIni           106664 non-null  object
#  23  BersaljuBesok             106664 non-null  object
# dtypes: float64(16), int64(1), object(7)
# memory usage: 20.0+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18182 entries, 0 to 18181
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tanggal                   18182 non-null  object
#  1   KodeLokasi                18182 non-null  object
#  2   SuhuMin                   18017 non-null  float64
#  3   SuhuMax                   18017 non-null  float64
#  4   Hujan                     17795 non-null  float64
#  5   Penguapan                 10326 non-null  float64
#  6   SinarMatahari             9464 non-null   float64
#  7   ArahAnginTerkencang       16901 non-null  object
#  8   KecepatanAnginTerkencang  16908 non-null  float64
#  9   ArahAngin9am              16874 non-null  object
#  10  ArahAngin3pm              17686 non-null  object
#  11  KecepatanAngin9am         17984 non-null  float64
#  12  KecepatanAngin3pm         17828 non-null  float64
#  13  Kelembaban9am             17852 non-null  float64
#  14  Kelembaban3pm             17634 non-null  float64
#  15  Tekanan9am                16317 non-null  float64
#  16  Tekanan3pm                16329 non-null  float64
#  17  Awan9am                   11140 non-null  float64
#  18  Awan3pm                   10726 non-null  float64
#  19  Suhu9am                   17963 non-null  float64
#  20  Suhu3pm                   17740 non-null  float64
#  21  BersaljuHariIni           17795 non-null  object
#  22  BersaljuBesok             17763 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 3.2+ MB

# %%
train_data.head()
# Out:
#    id     Tanggal KodeLokasi  SuhuMin  SuhuMax  Hujan  Penguapan  \
# 0   1  01/06/2014         C4     10.4     15.5    4.8        NaN
# 1   2  15/07/2014        C10      9.0     17.0    8.0        2.6
# 2   3  16/02/2011        C46     18.2     32.0    0.0        NaN
# 3   4  08/08/2012        C36      7.3     24.5    0.0        8.4
# 4   5  29/10/2016         C7      5.9     20.3    0.0        3.6
#
#    SinarMatahari ArahAnginTerkencang  KecepatanAnginTerkencang  ...  \
# 0            NaN                 WSW                      24.0  ...
# 1            7.4                 NaN                       NaN  ...
# 2            NaN                 ESE                      44.0  ...
# 3           10.4                 SSW                      54.0  ...
# 4           12.6                   N                      37.0  ...
#
#   Kelembaban9am Kelembaban3pm  Tekanan9am  Tekanan3pm  Awan9am  Awan3pm  \
# 0          78.0          76.0      1020.1      1018.5      NaN      NaN
# 1          80.0          61.0      1015.2      1014.6      7.0      5.0
# 2          62.0          42.0         NaN         NaN      NaN      NaN
# 3          25.0          17.0      1019.2      1016.9      1.0      7.0
# 4          55.0          48.0      1019.7      1014.7      2.0      6.0
#
#    Suhu9am  Suhu3pm  BersaljuHariIni  BersaljuBesok
# 0     13.1     15.0               Ya          Tidak
# 1     11.9     15.5               Ya             Ya
# 2     23.8     29.6            Tidak          Tidak
# 3     15.3     23.2            Tidak          Tidak
# 4     12.4     18.1            Tidak          Tidak
#
# [5 rows x 24 columns]

# %%
train_data.describe(include="all")
# Out:
#                    id     Tanggal KodeLokasi        SuhuMin        SuhuMax  \
# count   109095.000000      109095     109095  107973.000000  108166.000000
# unique            NaN        3414         49            NaN            NaN
# top               NaN  31/03/2017         C1            NaN            NaN
# freq              NaN          45       2598            NaN            NaN
# mean     54548.000000         NaN        NaN      12.196183      23.214819
# std      31493.158146         NaN        NaN       6.389419       7.106596
# min          1.000000         NaN        NaN      -8.500000      -4.800000
# 25%      27274.500000         NaN        NaN       7.600000      17.900000
# 50%      54548.000000         NaN        NaN      12.000000      22.600000
# 75%      81821.500000         NaN        NaN      16.800000      28.200000
# max     109095.000000         NaN        NaN      33.900000      47.300000
#
#                 Hujan     Penguapan  SinarMatahari ArahAnginTerkencang  \
# count   106664.000000  62071.000000   56716.000000              101351
# unique            NaN           NaN            NaN                  16
# top               NaN           NaN            NaN                   W
# freq              NaN           NaN            NaN                7491
# mean         2.385005      5.462440       7.599527                 NaN
# std          8.588155      4.201638       3.789042                 NaN
# min          0.000000      0.000000       0.000000                 NaN
# 25%          0.000000      2.600000       4.800000                 NaN
# 50%          0.000000      4.800000       8.400000                 NaN
# 75%          0.800000      7.400000      10.600000                 NaN
# max        371.000000    145.000000      14.300000                 NaN
#
#         KecepatanAnginTerkencang  ...  Kelembaban9am  Kelembaban3pm  \
# count              101399.000000  ...  107093.000000  105721.000000
# unique                       NaN  ...            NaN            NaN
# top                          NaN  ...            NaN            NaN
# freq                         NaN  ...            NaN            NaN
# mean                   40.032002  ...      68.895577      51.567626
# std                    13.617554  ...      18.995528      20.791573
# min                     7.000000  ...       0.000000       0.000000
# 25%                    31.000000  ...      57.000000      37.000000
# 50%                    39.000000  ...      70.000000      52.000000
# 75%                    48.000000  ...      83.000000      66.000000
# max                   135.000000  ...     100.000000     100.000000
#
#           Tekanan9am    Tekanan3pm       Awan9am       Awan3pm        Suhu9am  \
# count   97768.000000  97787.000000  67251.000000  64624.000000  107755.000000
# unique           NaN           NaN           NaN           NaN            NaN
# top              NaN           NaN           NaN           NaN            NaN
# freq             NaN           NaN           NaN           NaN            NaN
# mean     1017.647080   1015.253117      4.450893      4.516140      16.991391
# std         7.117338      7.047875      2.884566      2.718738       6.477602
# min       980.500000    977.100000      0.000000      0.000000      -7.200000
# 25%      1012.900000   1010.400000      1.000000      2.000000      12.300000
# 50%      1017.600000   1015.200000      5.000000      5.000000      16.700000
# 75%      1022.400000   1020.000000      7.000000      7.000000      21.600000
# max      1041.000000   1039.600000      9.000000      9.000000      40.200000
#
#               Suhu3pm  BersaljuHariIni  BersaljuBesok
# count   106397.000000           106664         106664
# unique            NaN                2              2
# top               NaN            Tidak          Tidak
# freq              NaN            82670          82701
# mean        21.672771              NaN            NaN
# std          6.922833              NaN            NaN
# min         -5.400000              NaN            NaN
# 25%         16.600000              NaN            NaN
# 50%         21.100000              NaN            NaN
# 75%         26.400000              NaN            NaN
# max         46.700000              NaN            NaN
#
# [11 rows x 24 columns]

# %%
test_data.head()
# Out:
#       Tanggal KodeLokasi  SuhuMin  SuhuMax  Hujan  Penguapan  SinarMatahari  \
# 0  04/11/2010        C39     11.0     27.5    0.0        NaN            6.4
# 1  26/03/2015        C35     10.0     19.9    0.2        NaN            NaN
# 2  22/03/2016        C18      9.2     27.2    0.0        5.2           10.4
# 3  09/12/2011        C31     17.7     27.0    0.0        4.6            6.7
# 4  20/05/2017        C14      2.3      7.9   88.0        NaN            NaN
#
#   ArahAnginTerkencang  KecepatanAnginTerkencang ArahAngin9am  ...  \
# 0                 WSW                      46.0            W  ...
# 1                 WNW                      56.0            W  ...
# 2                 SSW                      33.0           NE  ...
# 3                  SW                      35.0            E  ...
# 4                  NW                      46.0            W  ...
#
#   Kelembaban9am  Kelembaban3pm  Tekanan9am  Tekanan3pm  Awan9am  Awan3pm  \
# 0          39.0           56.0      1013.0      1012.4      4.0      7.0
# 1          76.0           32.0      1017.0      1015.2      8.0      1.0
# 2          89.0           27.0      1018.6      1015.7      0.0      1.0
# 3          55.0           41.0      1010.2      1008.6      7.0      6.0
# 4          98.0           95.0         NaN         NaN      NaN      NaN
#
#    Suhu9am  Suhu3pm  BersaljuHariIni  BersaljuBesok
# 0     25.7     23.6               No             No
# 1     10.7     18.9               No            Yes
# 2     13.9     26.3               No             No
# 3     22.3     26.4               No             No
# 4      4.4      6.0              Yes             No
#
# [5 rows x 23 columns]

# %%
test_data.describe(include="all")
# Out:
#            Tanggal KodeLokasi       SuhuMin       SuhuMax         Hujan  \
# count        18182      18182  18017.000000  18017.000000  17795.000000
# unique        3151         49           NaN           NaN           NaN
# top     30/12/2013        C24           NaN           NaN           NaN
# freq            14        426           NaN           NaN           NaN
# mean           NaN        NaN     12.233158     23.295604      2.333560
# std            NaN        NaN      6.433053      7.156981      8.320407
# min            NaN        NaN     -7.600000     -2.500000      0.000000
# 25%            NaN        NaN      7.700000     18.000000      0.000000
# 50%            NaN        NaN     12.000000     22.700000      0.000000
# 75%            NaN        NaN     16.900000     28.300000      0.600000
# max            NaN        NaN     31.400000     48.100000    247.200000
#
#            Penguapan  SinarMatahari ArahAnginTerkencang  \
# count   10326.000000    9464.000000               16901
# unique           NaN            NaN                  16
# top              NaN            NaN                 SSE
# freq             NaN            NaN                1189
# mean        5.509646       7.630135                 NaN
# std         4.159158       3.796355                 NaN
# min         0.000000       0.000000                 NaN
# 25%         2.600000       4.900000                 NaN
# 50%         4.800000       8.400000                 NaN
# 75%         7.400000      10.700000                 NaN
# max        68.800000      14.500000                 NaN
#
#         KecepatanAnginTerkencang ArahAngin9am  ... Kelembaban9am  \
# count               16908.000000        16874  ...  17852.000000
# unique                       NaN           16  ...           NaN
# top                          NaN            N  ...           NaN
# freq                         NaN         1460  ...           NaN
# mean                   39.974095          NaN  ...     68.791676
# std                    13.491682          NaN  ...     19.158606
# min                     6.000000          NaN  ...      2.000000
# 25%                    31.000000          NaN  ...     57.000000
# 50%                    39.000000          NaN  ...     70.000000
# 75%                    48.000000          NaN  ...     83.000000
# max                   122.000000          NaN  ...    100.000000
#
#         Kelembaban3pm   Tekanan9am    Tekanan3pm       Awan9am       Awan3pm  \
# count    17634.000000  16317.00000  16329.000000  11140.000000  10726.000000
# unique            NaN          NaN           NaN           NaN           NaN
# top               NaN          NaN           NaN           NaN           NaN
# freq              NaN          NaN           NaN           NaN           NaN
# mean        51.438811   1017.56166   1015.181064      4.449820      4.498322
# std         20.799233      7.14728      7.072656      2.890697      2.725233
# min          1.000000    982.30000    984.500000      0.000000      0.000000
# 25%         36.000000   1012.90000   1010.400000      1.000000      2.000000
# 50%         52.000000   1017.60000   1015.200000      5.000000      5.000000
# 75%         66.000000   1022.30000   1019.900000      7.000000      7.000000
# max        100.000000   1040.60000   1038.400000      8.000000      8.000000
#
#              Suhu9am       Suhu3pm  BersaljuHariIni  BersaljuBesok
# count   17963.000000  17740.000000            17795          17763
# unique           NaN           NaN                2              2
# top              NaN           NaN               No             No
# freq             NaN           NaN            13830          13824
# mean       17.048945     21.774408              NaN            NaN
# std         6.524556      6.978095              NaN            NaN
# min        -5.200000     -3.700000              NaN            NaN
# 25%        12.300000     16.700000              NaN            NaN
# 50%        16.800000     21.200000              NaN            NaN
# 75%        21.600000     26.600000              NaN            NaN
# max        37.700000     46.100000              NaN            NaN
#
# [11 rows x 23 columns]

# %% [markdown]
# ### Preprocessing Data

# %% [markdown]
# ### Untuk clustering, kolom bersalju besok di drop

# %%
train_df = train_data.drop(["id","BersaljuBesok"], axis=1)
test_df = test_data.drop(["BersaljuBesok"], axis=1)
datasets = [train_df, test_df]

# %% [markdown]
# ### Mengisi missing value pada data numerikal

# %%
col = datasets[0].select_dtypes("number").columns
datasets[0].loc[:,col].describe()
# Out:
#              SuhuMin        SuhuMax          Hujan     Penguapan  \
# count  107973.000000  108166.000000  106664.000000  62071.000000
# mean       12.196183      23.214819       2.385005      5.462440
# std         6.389419       7.106596       8.588155      4.201638
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      47.300000     371.000000    145.000000
#
#        SinarMatahari  KecepatanAnginTerkencang  KecepatanAngin9am  \
# count   56716.000000             101399.000000      107742.000000
# mean        7.599527                 40.032002          14.052115
# std         3.789042                 13.617554           8.926092
# min         0.000000                  7.000000           0.000000
# 25%         4.800000                 31.000000           7.000000
# 50%         8.400000                 39.000000          13.000000
# 75%        10.600000                 48.000000          19.000000
# max        14.300000                135.000000         130.000000
#
#        KecepatanAngin3pm  Kelembaban9am  Kelembaban3pm    Tekanan9am  \
# count      106792.000000  107093.000000  105721.000000  97768.000000
# mean           18.677579      68.895577      51.567626   1017.647080
# std             8.830199      18.995528      20.791573      7.117338
# min             0.000000       0.000000       0.000000    980.500000
# 25%            13.000000      57.000000      37.000000   1012.900000
# 50%            19.000000      70.000000      52.000000   1017.600000
# 75%            24.000000      83.000000      66.000000   1022.400000
# max            87.000000     100.000000     100.000000   1041.000000
#
#          Tekanan3pm       Awan9am       Awan3pm        Suhu9am        Suhu3pm
# count  97787.000000  67251.000000  64624.000000  107755.000000  106397.000000
# mean    1015.253117      4.450893      4.516140      16.991391      21.672771
# std        7.047875      2.884566      2.718738       6.477602       6.922833
# min      977.100000      0.000000      0.000000      -7.200000      -5.400000
# 25%     1010.400000      1.000000      2.000000      12.300000      16.600000
# 50%     1015.200000      5.000000      5.000000      16.700000      21.100000
# 75%     1020.000000      7.000000      7.000000      21.600000      26.400000
# max     1039.600000      9.000000      9.000000      40.200000      46.700000

# %%
datasets[1].loc[:,col].describe()
# Out:
#             SuhuMin       SuhuMax         Hujan     Penguapan  SinarMatahari  \
# count  18017.000000  18017.000000  17795.000000  10326.000000    9464.000000
# mean      12.233158     23.295604      2.333560      5.509646       7.630135
# std        6.433053      7.156981      8.320407      4.159158       3.796355
# min       -7.600000     -2.500000      0.000000      0.000000       0.000000
# 25%        7.700000     18.000000      0.000000      2.600000       4.900000
# 50%       12.000000     22.700000      0.000000      4.800000       8.400000
# 75%       16.900000     28.300000      0.600000      7.400000      10.700000
# max       31.400000     48.100000    247.200000     68.800000      14.500000
#
#        KecepatanAnginTerkencang  KecepatanAngin9am  KecepatanAngin3pm  \
# count              16908.000000       17984.000000       17828.000000
# mean                  39.974095          13.971864          18.585540
# std                   13.491682           8.828422           8.748586
# min                    6.000000           0.000000           0.000000
# 25%                   31.000000           7.000000          13.000000
# 50%                   39.000000          13.000000          17.000000
# 75%                   48.000000          19.000000          24.000000
# max                  122.000000          83.000000          83.000000
#
#        Kelembaban9am  Kelembaban3pm   Tekanan9am    Tekanan3pm       Awan9am  \
# count   17852.000000   17634.000000  16317.00000  16329.000000  11140.000000
# mean       68.791676      51.438811   1017.56166   1015.181064      4.449820
# std        19.158606      20.799233      7.14728      7.072656      2.890697
# min         2.000000       1.000000    982.30000    984.500000      0.000000
# 25%        57.000000      36.000000   1012.90000   1010.400000      1.000000
# 50%        70.000000      52.000000   1017.60000   1015.200000      5.000000
# 75%        83.000000      66.000000   1022.30000   1019.900000      7.000000
# max       100.000000     100.000000   1040.60000   1038.400000      8.000000
#
#             Awan3pm       Suhu9am       Suhu3pm
# count  10726.000000  17963.000000  17740.000000
# mean       4.498322     17.048945     21.774408
# std        2.725233      6.524556      6.978095
# min        0.000000     -5.200000     -3.700000
# 25%        2.000000     12.300000     16.700000
# 50%        5.000000     16.800000     21.200000
# 75%        7.000000     21.600000     26.600000
# max        8.000000     37.700000     46.100000

# %% [markdown]
# Drop kolom yang memiliki banyak data null

# %%
datasets[0].drop(["Penguapan", "SinarMatahari", "Awan9am", "Awan3pm"], axis=1, inplace=True)
datasets[0].shape
# Out:
# (109095, 18)

# %% [markdown]
# ### # Ekperimen data
# Membuat dataset ekperimen dengan pengisian null dengan nilai 0 dan modus

# %%
col = datasets[0].select_dtypes("number").columns
df_ex_zero = datasets.copy()
df_ex_mode = datasets.copy()

# %%
for df in df_ex_zero:  
    col = df.select_dtypes("number").columns
    for x in col:
        df[x].fillna(0, inplace=True)

# %%
for df in df_ex_mode:  
    col = df.select_dtypes("number").columns
    for x in col:
        df[x].fillna(df[x].mode().iloc[0], inplace=True)

# %%
df_ex_zero[0].select_dtypes("number").isna().sum()
# Out:
# SuhuMin                     0
# SuhuMax                     0
# Hujan                       0
# KecepatanAnginTerkencang    0
# KecepatanAngin9am           0
# KecepatanAngin3pm           0
# Kelembaban9am               0
# Kelembaban3pm               0
# Tekanan9am                  0
# Tekanan3pm                  0
# Suhu9am                     0
# Suhu3pm                     0
# dtype: int64

# %%
df_ex_zero[0].select_dtypes("number").isna().sum()
# Out:
# SuhuMin                     0
# SuhuMax                     0
# Hujan                       0
# KecepatanAnginTerkencang    0
# KecepatanAngin9am           0
# KecepatanAngin3pm           0
# Kelembaban9am               0
# Kelembaban3pm               0
# Tekanan9am                  0
# Tekanan3pm                  0
# Suhu9am                     0
# Suhu3pm                     0
# dtype: int64

# %% [markdown]
# ### Menghilangkan outlier pada dataset

# %%
# IQR untuk df_ex_zero
i = 0
for df in df_ex_zero:
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    iqr = q3 - q1
    low_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df_ex_zero[i] = df[~((df < (q1 - 1.5 * iqr)) |(df > (q3 + 1.5 * iqr))).any(axis=1)]
    df_ex_zero[i].reset_index(drop=True, inplace=True)
    i += 1
# Out:
# <ipython-input-17-2b8b24de3df5>:9: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_ex_zero[i] = df[~((df < (q1 - 1.5 * iqr)) |(df > (q3 + 1.5 * iqr))).any(axis=1)]

# %%
print("shape data train: ",df_ex_zero[0].shape)
print("shape data test: ",df_ex_zero[1].shape)
# Out:
# shape data train:  (70498, 18)
# shape data test:  (11509, 22)

# %%
# IQR untuk df_ex_mode
i = 0
for df in df_ex_mode:
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    iqr = q3 - q1
    low_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df_ex_mode[i] = df[~((df < (q1 - 1.5 * iqr)) |(df > (q3 + 1.5 * iqr))).any(axis=1)]
    df_ex_mode[i].reset_index(drop=True, inplace=True)
    i += 1
# Out:
# <ipython-input-19-8d3c54bd0841>:9: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_ex_mode[i] = df[~((df < (q1 - 1.5 * iqr)) |(df > (q3 + 1.5 * iqr))).any(axis=1)]

# %%
print("shape data train: ",df_ex_mode[0].shape)
print("shape data test: ",df_ex_mode[1].shape)
# Out:
# shape data train:  (70498, 18)
# shape data test:  (11509, 22)

# %% [markdown]
# ### Normalisasi Data Numerikal
# Menggunakan MinMaxScaler

# %%
# Normalisiasi data train
def minMaxScaler(dataset):
    col = dataset.select_dtypes("number").columns
    col_idx = []
    
    # Mencari nilai min dan max setiap kolom
    for column in col:
        col_idx.append(dataset.columns.get_loc(column))
    min_val = dataset.iloc[:, col_idx].min()
    max_val = dataset.iloc[:, col_idx].max()
    
    # Melakukan scaling untuk setiap baris
    for row in range(len(dataset)):
        for i in range(len(col_idx)):
            dataset.iloc[row, col_idx[i]] = (dataset.iloc[row, col_idx[i]] - min_val[i]) / (max_val[i] - min_val[i])
    return dataset

# %% [markdown]
# Dikarenakan keterbatasan kemampuan komputer, sehingga hanya akan diambil sampel data saja

# %%
# scaling data df_ex_zero
df_ex_zero[0] = minMaxScaler(df_ex_zero[0].iloc[:10000])
df_ex_zero[1] = minMaxScaler(df_ex_zero[1].iloc[:4000])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# scaling data df_ex_mode
df_ex_mode[0] = minMaxScaler(df_ex_mode[0].iloc[:10000])
df_ex_mode[1] = minMaxScaler(df_ex_mode[1].iloc[:4000])

# %% [markdown]
# ### Mengisi missing value pada data kategorikal

# %%
for df in df_ex_zero:    
    col_cat= df.select_dtypes(include="object").columns
    for col in col_cat:
        df[col].fillna(df[col].mode().iloc[0], inplace=True)

# %%
for df in df_ex_mode:    
    col_cat= df.select_dtypes(include="object").columns
    for col in col_cat:
        df[col].fillna(df[col].mode().iloc[0], inplace=True)

# %%
df_ex_zero[0].select_dtypes("object").isna().sum()
# Out:
# Tanggal                0
# KodeLokasi             0
# ArahAnginTerkencang    0
# ArahAngin9am           0
# ArahAngin3pm           0
# BersaljuHariIni        0
# dtype: int64

# %%
df_ex_mode[0].select_dtypes("object").isna().sum()
# Out:
# Tanggal                0
# KodeLokasi             0
# ArahAnginTerkencang    0
# ArahAngin9am           0
# ArahAngin3pm           0
# BersaljuHariIni        0
# dtype: int64

# %% [markdown]
# ### Encode data kategorikal

# %%
# Encode df_ex_zero
i = 0
for df in df_ex_zero:
    # drop kolom tanggal dan kode lokasi karena terlalu banyak nilai uniknya
    df.drop(["Tanggal","KodeLokasi"], axis=1, inplace=True)
    
    # encode untuk nilai "Ya" dan "Tidak" pada df_ex_zero
    df.replace({"Ya": 1, "Tidak": 0}, inplace=True)
    
    # menerapkan OHE dengan memanggil get_dummies untuk setiap data kategorikal yang ada
    col_cat = df.select_dtypes(include="object").columns
    df_ex_zero[i] = pd.get_dummies(df, columns=col_cat)
    i += 1

# %%
# Encode df_ex_mode
i = 0
for df in df_ex_mode:
    # drop kolom tanggal dan kode lokasi karena terlalu banyak nilai uniknya
    df.drop(["Tanggal","KodeLokasi"], axis=1, inplace=True)
    
    # encode untuk nilai "Ya" dan "Tidak" pada df_ex_mode
    df.replace({"Ya": 1, "Tidak": 0}, inplace=True)
    
    # menerapkan OHE dengan memanggil get_dummies untuk setiap data kategorikal yang ada
    col_cat = df.select_dtypes(include="object").columns
    df_ex_mode[i] = pd.get_dummies(df, columns=col_cat)
    i += 1

# %%
df_ex_zero[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 61 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SuhuMin                   10000 non-null  float64
#  1   SuhuMax                   10000 non-null  float64
#  2   Hujan                     10000 non-null  float64
#  3   KecepatanAnginTerkencang  10000 non-null  float64
#  4   KecepatanAngin9am         10000 non-null  float64
#  5   KecepatanAngin3pm         10000 non-null  float64
#  6   Kelembaban9am             10000 non-null  float64
#  7   Kelembaban3pm             10000 non-null  float64
#  8   Tekanan9am                10000 non-null  float64
#  9   Tekanan3pm                10000 non-null  float64
#  10  Suhu9am                   10000 non-null  float64
#  11  Suhu3pm                   10000 non-null  float64
#  12  BersaljuHariIni           10000 non-null  int64
#  13  ArahAnginTerkencang_E     10000 non-null  uint8
#  14  ArahAnginTerkencang_ENE   10000 non-null  uint8
#  15  ArahAnginTerkencang_ESE   10000 non-null  uint8
#  16  ArahAnginTerkencang_N     10000 non-null  uint8
#  17  ArahAnginTerkencang_NE    10000 non-null  uint8
#  18  ArahAnginTerkencang_NNE   10000 non-null  uint8
#  19  ArahAnginTerkencang_NNW   10000 non-null  uint8
#  20  ArahAnginTerkencang_NW    10000 non-null  uint8
#  21  ArahAnginTerkencang_S     10000 non-null  uint8
#  22  ArahAnginTerkencang_SE    10000 non-null  uint8
#  23  ArahAnginTerkencang_SSE   10000 non-null  uint8
#  24  ArahAnginTerkencang_SSW   10000 non-null  uint8
#  25  ArahAnginTerkencang_SW    10000 non-null  uint8
#  26  ArahAnginTerkencang_W     10000 non-null  uint8
#  27  ArahAnginTerkencang_WNW   10000 non-null  uint8
#  28  ArahAnginTerkencang_WSW   10000 non-null  uint8
#  29  ArahAngin9am_E            10000 non-null  uint8
#  30  ArahAngin9am_ENE          10000 non-null  uint8
#  31  ArahAngin9am_ESE          10000 non-null  uint8
#  32  ArahAngin9am_N            10000 non-null  uint8
#  33  ArahAngin9am_NE           10000 non-null  uint8
#  34  ArahAngin9am_NNE          10000 non-null  uint8
#  35  ArahAngin9am_NNW          10000 non-null  uint8
#  36  ArahAngin9am_NW           10000 non-null  uint8
#  37  ArahAngin9am_S            10000 non-null  uint8
#  38  ArahAngin9am_SE           10000 non-null  uint8
#  39  ArahAngin9am_SSE          10000 non-null  uint8
#  40  ArahAngin9am_SSW          10000 non-null  uint8
#  41  ArahAngin9am_SW           10000 non-null  uint8
#  42  ArahAngin9am_W            10000 non-null  uint8
#  43  ArahAngin9am_WNW          10000 non-null  uint8
#  44  ArahAngin9am_WSW          10000 non-null  uint8
#  45  ArahAngin3pm_E            10000 non-null  uint8
#  46  ArahAngin3pm_ENE          10000 non-null  uint8
#  47  ArahAngin3pm_ESE          10000 non-null  uint8
#  48  ArahAngin3pm_N            10000 non-null  uint8
#  49  ArahAngin3pm_NE           10000 non-null  uint8
#  50  ArahAngin3pm_NNE          10000 non-null  uint8
#  51  ArahAngin3pm_NNW          10000 non-null  uint8
#  52  ArahAngin3pm_NW           10000 non-null  uint8
#  53  ArahAngin3pm_S            10000 non-null  uint8
#  54  ArahAngin3pm_SE           10000 non-null  uint8
#  55  ArahAngin3pm_SSE          10000 non-null  uint8
#  56  ArahAngin3pm_SSW          10000 non-null  uint8
#  57  ArahAngin3pm_SW           10000 non-null  uint8
#  58  ArahAngin3pm_W            10000 non-null  uint8
#  59  ArahAngin3pm_WNW          10000 non-null  uint8
#  60  ArahAngin3pm_WSW          10000 non-null  uint8
# dtypes: float64(12), int64(1), uint8(48)
# memory usage: 1.4 MB

# %%
df_ex_mode[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 61 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SuhuMin                   10000 non-null  float64
#  1   SuhuMax                   10000 non-null  float64
#  2   Hujan                     10000 non-null  float64
#  3   KecepatanAnginTerkencang  10000 non-null  float64
#  4   KecepatanAngin9am         10000 non-null  float64
#  5   KecepatanAngin3pm         10000 non-null  float64
#  6   Kelembaban9am             10000 non-null  float64
#  7   Kelembaban3pm             10000 non-null  float64
#  8   Tekanan9am                10000 non-null  float64
#  9   Tekanan3pm                10000 non-null  float64
#  10  Suhu9am                   10000 non-null  float64
#  11  Suhu3pm                   10000 non-null  float64
#  12  BersaljuHariIni           10000 non-null  int64
#  13  ArahAnginTerkencang_E     10000 non-null  uint8
#  14  ArahAnginTerkencang_ENE   10000 non-null  uint8
#  15  ArahAnginTerkencang_ESE   10000 non-null  uint8
#  16  ArahAnginTerkencang_N     10000 non-null  uint8
#  17  ArahAnginTerkencang_NE    10000 non-null  uint8
#  18  ArahAnginTerkencang_NNE   10000 non-null  uint8
#  19  ArahAnginTerkencang_NNW   10000 non-null  uint8
#  20  ArahAnginTerkencang_NW    10000 non-null  uint8
#  21  ArahAnginTerkencang_S     10000 non-null  uint8
#  22  ArahAnginTerkencang_SE    10000 non-null  uint8
#  23  ArahAnginTerkencang_SSE   10000 non-null  uint8
#  24  ArahAnginTerkencang_SSW   10000 non-null  uint8
#  25  ArahAnginTerkencang_SW    10000 non-null  uint8
#  26  ArahAnginTerkencang_W     10000 non-null  uint8
#  27  ArahAnginTerkencang_WNW   10000 non-null  uint8
#  28  ArahAnginTerkencang_WSW   10000 non-null  uint8
#  29  ArahAngin9am_E            10000 non-null  uint8
#  30  ArahAngin9am_ENE          10000 non-null  uint8
#  31  ArahAngin9am_ESE          10000 non-null  uint8
#  32  ArahAngin9am_N            10000 non-null  uint8
#  33  ArahAngin9am_NE           10000 non-null  uint8
#  34  ArahAngin9am_NNE          10000 non-null  uint8
#  35  ArahAngin9am_NNW          10000 non-null  uint8
#  36  ArahAngin9am_NW           10000 non-null  uint8
#  37  ArahAngin9am_S            10000 non-null  uint8
#  38  ArahAngin9am_SE           10000 non-null  uint8
#  39  ArahAngin9am_SSE          10000 non-null  uint8
#  40  ArahAngin9am_SSW          10000 non-null  uint8
#  41  ArahAngin9am_SW           10000 non-null  uint8
#  42  ArahAngin9am_W            10000 non-null  uint8
#  43  ArahAngin9am_WNW          10000 non-null  uint8
#  44  ArahAngin9am_WSW          10000 non-null  uint8
#  45  ArahAngin3pm_E            10000 non-null  uint8
#  46  ArahAngin3pm_ENE          10000 non-null  uint8
#  47  ArahAngin3pm_ESE          10000 non-null  uint8
#  48  ArahAngin3pm_N            10000 non-null  uint8
#  49  ArahAngin3pm_NE           10000 non-null  uint8
#  50  ArahAngin3pm_NNE          10000 non-null  uint8
#  51  ArahAngin3pm_NNW          10000 non-null  uint8
#  52  ArahAngin3pm_NW           10000 non-null  uint8
#  53  ArahAngin3pm_S            10000 non-null  uint8
#  54  ArahAngin3pm_SE           10000 non-null  uint8
#  55  ArahAngin3pm_SSE          10000 non-null  uint8
#  56  ArahAngin3pm_SSW          10000 non-null  uint8
#  57  ArahAngin3pm_SW           10000 non-null  uint8
#  58  ArahAngin3pm_W            10000 non-null  uint8
#  59  ArahAngin3pm_WNW          10000 non-null  uint8
#  60  ArahAngin3pm_WSW          10000 non-null  uint8
# dtypes: float64(12), int64(1), uint8(48)
# memory usage: 1.4 MB

# %% [markdown]
# ### Export dataset

# %%
df_ex_zero[0].to_csv('salju_train_preprocess_zero.csv', encoding='utf-8', index=False)
df_ex_zero[1].to_csv('salju_test_preprocess_zero.csv', encoding='utf-8', index=False)

# %%
df_ex_mode[0].to_csv('salju_train_preprocess_mode.csv', encoding='utf-8', index=False)
df_ex_mode[1].to_csv('salju_test_preprocess_mode.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Mencari feature untuk model
# Karena dimensi data sangat besar, maka dilakukan pemilihan feature yang akan digunakan ke dalam K-means, sehingga feature "Tekanan3pm" dan "SuhuMin" yang dipilih untuk diuji

# %%
X_zero = df_ex_zero[0].loc[:, ["Tekanan3pm", "SuhuMin"]]
X_zero
# Out:
#       Tekanan3pm   SuhuMin
# 0       0.560185  0.367978
# 1       0.509259  0.328652
# 2       0.458333  0.567416
# 3       0.372685  0.379213
# 4       0.479167  0.679775
# ...          ...       ...
# 9995    0.546296  0.679775
# 9996    0.733796  0.320225
# 9997    0.856481  0.418539
# 9998    0.643519  0.617978
# 9999    0.428241  0.752809
#
# [10000 rows x 2 columns]

# %%
X_mode = df_ex_mode[0].loc[:, ["Tekanan3pm", "SuhuMin"]]
X_mode
# Out:
#       Tekanan3pm   SuhuMin
# 0       0.560185  0.367978
# 1       0.509259  0.328652
# 2       0.458333  0.567416
# 3       0.372685  0.379213
# 4       0.479167  0.679775
# ...          ...       ...
# 9995    0.546296  0.679775
# 9996    0.733796  0.320225
# 9997    0.856481  0.418539
# 9998    0.643519  0.617978
# 9999    0.428241  0.752809
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## Pembuatan Model

# %% [markdown]
# ### Pembuatan fungsi Euclidean Distance

# %%
def euclideanDist(x1, x2):
    temp = 0
    for i in range(len(x1)):
        temp += np.square(x1[i] - x2[i])
        result = np.sqrt(temp)
    return result

# %%
def predDist(data_class, centroid):
    temp = 0
    for i in range(len(data_class)):
        for j in range(len(centroid)):
            temp += np.square(data_class[i] - centroid[j])
    result = np.sqrt(temp)
    return result

# %% [markdown]
# ### Pembuatan fungsi K-Means

# %%
class kMeans:
    def __init__(self, k, tres, n_iter):
        self.k = k
        self.treshold = tres
        self.n_iter = n_iter
    
    def fit(self, x):
        # Inisiasi centroid awal
        self.centroids = {}
        for a in range(self.k):
            self.centroids[a] = x.iloc[a]

        # Melakukan klasifikasi data sesuai dengan centroidnya
        for i in range(self.n_iter):

            # Mendefinisikan kelas data
            self.data_class = {}

            for b in range(self.k):
                self.data_class[b] = []

            # Menghitung jarak dan melakukan klasifikasi
            for n in range(len(x)):
                dist = []
                for j in self.centroids:
                    res = euclideanDist(x.iloc[n], self.centroids[j])
                    dist.append(res)

                min_dist_idx = dist.index(min(dist))
                self.data_class[min_dist_idx].append(x.iloc[n])

            # Inisiasi centroid lama
            old_centroids = dict(self.centroids)

            # Menentukan centroid baru dengan menghitung rata-rata point pada setiap kluster
            for key in self.data_class:
                c_data = self.data_class[key]
                new_centro = np.average(c_data, axis = 0)
                self.centroids[key] = new_centro


            # Cek kondisi centroid apakah ganti atau tidak
            isOptimal = True

            for c in self.centroids:
                old_centroid = old_centroids[c]
                curr_centroid = self.centroids[c]
                if np.sum( (curr_centroid - old_centroid) / old_centroid * 100.0) > self.treshold:
                    isOptimal = False
            if isOptimal:
                break

    def predict(self, x):
        data_class = {}
        for b in range(self.k):
            data_class[b] = []
        for n in range(len(x)):
            dist = []
            for j in self.centroids:
                res = predDist(x.iloc[n], self.centroids[j])
                dist.append(res)

            min_dist_idx = dist.index(min(dist))
            data_class[min_dist_idx].append(x.iloc[n])
        return data_class

# %% [markdown]
# ## Evaluasi Model

# %% [markdown]
# ### Pembuatan fungsi hitung Silhoutte Coefficient

# %%
def silhouetteCoef(data_class):
    intra_res = []
    inter_res = []
    for idx in range(len(data_class)):
        init_point = data_class[idx][0]
        inter_dist = 0
        intra_dist = 0
        
        # Menghitung intra-cluster distance 
        for point in range(1, len(data_class[idx])):
            intra_dist += euclideanDist(init_point, data_class[idx][point])
        intra_res.append(intra_dist / len(data_class[idx]))     
        
        # Menghitung inter-cluster distance
        next_idx = idx + 1
        while next_idx < len(data_class):
            for point in range(len(data_class[next_idx])):
                inter_dist += euclideanDist(init_point, data_class[next_idx][point])
            inter_res.append(inter_dist / len(data_class[next_idx]))
            next_idx += 1

    inter_res = np.mean(inter_res)
    intra_res = np.mean(intra_res)
    return (inter_res - intra_res) / max(intra_res, inter_res)

# %% [markdown]
# ## Eksperimen

# %% [markdown]
# ### Perbandingan performa K-means untuk setiap dataset eksperimen

# %%
# K-means dengan dataset X_zero
k = []
sil = []
for i in range(2,8):
    k.append(i)
    model = kMeans(i, 0.001, 50)
    model.fit(X_zero)
    sil_res = silhouetteCoef(model.data_class)
    sil.append(1- sil_res)

# %%
plt.plot(k, sil, linestyle='solid', c='r')
plt.ylabel("1 - silhouette coef.")
plt.xlabel("number of k")
plt.show()

# %%
# K-means dengan dataset X_mode
k = []
sil = []
for i in range(2,7):
    k.append(i)
    model = kMeans(i, 0.001, 50)
    model.fit(X_mode)
    sil_res = silhouetteCoef(model.data_class)
    sil.append(1- sil_res)

# %%
plt.plot(k, sil, linestyle='solid', c='b')
plt.ylabel("1 - silhouette coef.")
plt.xlabel("number of k")
plt.show()

# %% [markdown]
# Hasil silhouette coef sama, hal ini mengindikasikan bahwa 10000 data pertama tidak mempengaruhi K-means

# %% [markdown]
# ### Eksperimen dengan mengganti parameter k

# %%
# Silhouette Coef k: 3 pada model sebelumnya
print("prev = k: ",k[1], "-> Silhouette Coef: ",1 - sil[1])
# Out:
# prev = k:  3 -> Silhouette Coef:  0.7576764491498857

# %%
# Ujicoba k: 3 dengan parameter baru
model_new = kMeans(3, 0.0001, 50)
model_new.fit(X_mode)
print("k: ",3," -> Silhouette Coef: ",silhouetteCoef(model.data_class))
# Out:
# k:  3  -> Silhouette Coef:  0.8504003172100483

# %% [markdown]
# Hasil silhouette menunjukkan bahwa model K-means dengan parameter k=3, treshold=0.001, dan iterasi=50 memiliki Silhouette coef lebih kecil daripada K-means dengan treshold=0.0001, dan iterasi=50

# %% [markdown]
# ### Visualisasi data training
# Menggunakan model k-means dengan parameter k=3 , treshold=0.0001, dan iterasi=50

# %%
cmap = {0 : 'r',1 : 'b', 2: 'darkgreen', 3: 'm', 4: 'y', 5: 'darkorange', 6: 'c', 7: 'darkviolet'}

label_color = [cmap[l] for l in model.data_class]
plt.figure(figsize=(10,8))

for centroid in model_new.centroids:
    plt.scatter(model_new.centroids[centroid][0], model_new.centroids[centroid][1], marker="*", color='k', s=150, linewidths=5)
    
for idx_class in model_new.data_class:
    for idx_data in range(len(model_new.data_class[idx_class])):
        plt.scatter(model_new.data_class[idx_class][idx_data][0], model_new.data_class[idx_class][idx_data][1] , c=label_color[idx_class])
plt.show()

# %% [markdown]
# ### Prediksi data test

# %%
# Prediksi data test df_ex_zero
pred = model_new.predict(df_ex_zero[1])

# %%
for idx_class in pred:
    for idx_data in range(len(pred[idx_class])):
        plt.scatter(pred[idx_class][idx_data][0], pred[idx_class][idx_data][1] , c=label_color[idx_class])
plt.show()

# %% [markdown]
# Seluruh data test tergabung ke dalam cluster biru

# %% [markdown]
# ## Kesimpulan
# Parameter terbaik pada model K-means ini untuk dataset salju dengan jumlah data 10.000 data adalah k=3 , treshold=0.0001, dan iterasi=50. Unutuk memprediksi besok bersalju atau tidak, dapat dilakukan dengan cara menentukan untuk setiap kelompok data apakah kemumngkinan kelompok data tersebut menunjukkan terjadinya salju atau tidak.
